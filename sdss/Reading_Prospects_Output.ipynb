# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
sed_fit = pd.read_csv('./prospect_test.csv')

# %%
plt.plot(sed_fit['FinalFlux.wave'], sed_fit['FinalFlux.flux'], '-')
plt.yscale('log')
plt.show()
