# %% [markdown]
# # Plot parameters

# %%
plotpars = {'axes.labelsize': 18,
            'axes.linewidth': 1.,
            'figure.figsize': (7.,5.),
            'font.size': 20,
            'legend.frameon': True,
            'legend.framealpha': 0.85,
            'legend.edgecolor': 'black',
            'legend.loc': 'best',
            'legend.fontsize': 12,
            'mathtext.fontset': 'stixsans',
            'savefig.bbox': 'tight',
            'xtick.labelsize': 18,
            'ytick.labelsize': 18,
           }

# %% [markdown]
# # Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from astropy.constants import c

# %% [markdown]
# # Data

# %%
data_path = './../../Data/'

# %%
stripe01 = pd.read_csv(os.path.join(data_path, 'Stripe82_1half_01.csv'))

# %%
stripe02 = pd.read_csv(os.path.join(data_path, 'Stripe82_2half_01.csv'))

# %%
stripe82_all = pd.concat([stripe01, stripe02], ignore_index=True)

# %% [markdown]
# # Offsets

# %% [markdown]
# See Doi et al. 2010

# %%
offset_u = -0.04
offset_g = +0.01
offset_r = +0.01
offset_i = +0.01
offset_z = +0.02

# %% [markdown]
# # AB magnitudes

# %%
mag_ab_u = pd.DataFrame(stripe82_all['dered_u'] + stripe82_all['kcorrU'] + offset_u, columns=['mag_ab_u'])
mag_ab_g = pd.DataFrame(stripe82_all['dered_g'] + stripe82_all['kcorrG'] + offset_g, columns=['mag_ab_g'])
mag_ab_r = pd.DataFrame(stripe82_all['dered_r'] + stripe82_all['kcorrR'] + offset_r, columns=['mag_ab_r'])
mag_ab_i = pd.DataFrame(stripe82_all['dered_i'] + stripe82_all['kcorrI'] + offset_i, columns=['mag_ab_i'])
mag_ab_z = pd.DataFrame(stripe82_all['dered_z'] + stripe82_all['kcorrZ'] + offset_z, columns=['mag_ab_z'])

# %%
mags_ab = mag_ab_u.join([mag_ab_g, mag_ab_r, mag_ab_i, mag_ab_z])

# %%
stripe82_all = stripe82_all.join(mags_ab)

# %%
stripe82_all
# Out:
#                 DR16_objID            specObjID          ra       dec  \
# 0      1237656567038084185  1150704931510970368  311.933374 -1.112837
# 1      1237656567039001739  1151796201734039552  314.018234 -1.127987
# 2      1237656567574954805  1105665360851396608  311.938698 -0.835999
# 3      1237656568111825115  1256543103012071424  311.928066 -0.237977
# 4      1237656568111826622  1150720049795852288  311.897271 -0.382674
# ...                    ...                  ...         ...       ...
# 21536  1237678437018828951   462857867016300544   45.378932  1.021455
# 21537  1237678437018894577   462858141894207488   45.420426  0.902750
# 21538  1237678617436029268  1757649652217309184   41.515569  0.925301
# 21539  1237678617973424341   460659394422532096   42.845240  1.148501
# 21540  1237678617974538452   462857042382579712   45.384594  1.248257
#
#        modelMag_u  modelMag_g  modelMag_r  modelMag_i  modelMag_z  \
# 0        21.04576    19.13633    18.24454    17.80636    17.49794
# 1        20.76806    19.62210    19.13410    18.80635    18.65836
# 2        20.45433    18.53984    17.59312    17.19148    16.80270
# 3        17.69172    16.47214    16.03583    15.88817    15.80522
# 4        21.86385    20.02797    19.47907    19.11540    18.81272
# ...           ...         ...         ...         ...         ...
# 21536    19.63723    18.41523    17.84743    17.45326    17.25182
# 21537    19.67763    18.31304    17.75179    17.37725    17.12214
# 21538    20.04137    18.96305    18.49113    18.19909    18.07179
# 21539    19.83836    17.73394    16.77602    16.33247    15.98942
# 21540    19.38315    18.13665    17.50508    17.05358    16.82872
#
#        modelMagErr_u  ...  absMagZ   lumDist    nnAvgZ              nnObjID  \
# 0           0.213636  ... -20.3617  405.7430  0.091076  1237679254671458424
# 1           0.139655  ... -19.4515  447.8940  0.098819  1237674460415066308
# 2           0.091158  ... -21.4032  425.1830  0.095755  1237667735064871170
# 3           0.011567  ... -18.4658   67.5777  0.019784  1237651190824960243
# 4           0.507493  ... -19.5642  423.3730  0.111239  1237663543685611936
# ...              ...  ...      ...       ...       ...                  ...
# 21536       0.045510  ... -21.0927  445.9270  0.097447  1237661387615633723
# 21537       0.062890  ... -20.3582  299.7080  0.070572  1237678437018894577
# 21538       0.073861  ... -20.1827  442.0680  0.099090  1237678596462019208
# 21539       0.060716  ... -21.7030  350.7490  0.080606  1237658614132310130
# 21540       0.046288  ... -21.1194  356.1340  0.087341  1237665129096282459
#
#         nnSpecz  mag_ab_u  mag_ab_g  mag_ab_r  mag_ab_i  mag_ab_z
# 0      0.087848  20.74498  18.98129  18.12617  17.60448  17.35054
# 1      0.056180  20.23733  19.27104  18.89285  18.45722  18.42430
# 2      0.121572  20.31114  18.46772  17.42584  17.03764  16.65656
# 3      0.010717  17.32434  16.20703  15.86566  15.73882  15.70032
# 4      0.067058  21.45083  19.75673  19.30473  18.81682  18.62357
# ...         ...       ...       ...       ...       ...       ...
# 21536  0.103471  19.16071  18.10534  17.63430  17.15122  17.04182
# 21537  0.073942  19.24202  18.00389  17.56485  17.10578  16.94978
# 21538  0.114081  19.83455  18.86331  18.42336  18.00507  17.94215
# 21539  0.118846  19.73000  17.71565  16.66045  16.22319  15.89081
# 21540  0.058579  18.96241  17.85497  17.32899  16.78946  16.65760
#
# [21541 rows x 52 columns]

# %% [markdown]
# # Fluxes

# %%
wl_pivot_u = 3557
wl_pivot_g = 4702
wl_pivot_r = 6175
wl_pivot_i = 7491
wl_pivot_z = 8943

# %%
light_speed = c.to('m/s').value

# %%
flux_u = light_speed/(wl_pivot_u)**2 * 10**(-0.4*mag_ab_u.values+48.60)
flux_g = light_speed/(wl_pivot_u)**2 * 10**(-0.4*mag_ab_u.values+48.60)
flux_r = light_speed/(wl_pivot_u)**2 * 10**(-0.4*mag_ab_u.values+48.60)
flux_i = light_speed/(wl_pivot_u)**2 * 10**(-0.4*mag_ab_u.values+48.60)
flux_z = light_speed/(wl_pivot_u)**2 * 10**(-0.4*mag_ab_u.values+48.60)

# %% [markdown]
# # Signal-to-noise estimation and cut

# %%
s2n_mag_u = 1/stripe82_all['modelMagErr_u']
s2n_mag_g = 1/stripe82_all['modelMagErr_g']
s2n_mag_r = 1/stripe82_all['modelMagErr_r']
s2n_mag_i = 1/stripe82_all['modelMagErr_i']
s2n_mag_z = 1/stripe82_all['modelMagErr_z']

# %%
plt.rcParams.update(plotpars)
plt.hist(s2n_mag_r, bins=10)
plt.xlabel("S/N r-band")
plt.ylabel("Frequency")
# plt.yscale('log')
plt.text(300, 5000, "S/N min=%.2f" % s2n_mag_r.min(), fontsize=15)
plt.text(300, 4000, "S/N max=%.2f" % s2n_mag_r.max(), fontsize=15)
plt.text(300, 3000, "S/N median=%.2f" % s2n_mag_r.median(), fontsize=15)
plt.show()

# %%
s2n_mag_u_df = pd.DataFrame(1/stripe82_all['modelMagErr_u'].values, columns=['s2n_mag_u'])
s2n_mag_g_df = pd.DataFrame(1/stripe82_all['modelMagErr_g'].values, columns=['s2n_mag_g'])
s2n_mag_r_df = pd.DataFrame(1/stripe82_all['modelMagErr_r'].values, columns=['s2n_mag_r'])
s2n_mag_i_df = pd.DataFrame(1/stripe82_all['modelMagErr_i'].values, columns=['s2n_mag_i'])
s2n_mag_z_df = pd.DataFrame(1/stripe82_all['modelMagErr_z'].values, columns=['s2n_mag_z'])

# %%
s2n_all = s2n_mag_u_df.join([s2n_mag_g_df, s2n_mag_r_df, s2n_mag_i_df, s2n_mag_z_df])

# %%
stripe82_all = stripe82_all.join(s2n_all)

# %%
stripe82_all.to_csv('../../Data/stripe82_SDSS.csv', index=False)

# %%
stripe82_all
# Out:
#                 DR16_objID            specObjID          ra       dec  \
# 0      1237656567038084185  1150704931510970368  311.933374 -1.112837
# 1      1237656567039001739  1151796201734039552  314.018234 -1.127987
# 2      1237656567574954805  1105665360851396608  311.938698 -0.835999
# 3      1237656568111825115  1256543103012071424  311.928066 -0.237977
# 4      1237656568111826622  1150720049795852288  311.897271 -0.382674
# ...                    ...                  ...         ...       ...
# 21536  1237678437018828951   462857867016300544   45.378932  1.021455
# 21537  1237678437018894577   462858141894207488   45.420426  0.902750
# 21538  1237678617436029268  1757649652217309184   41.515569  0.925301
# 21539  1237678617973424341   460659394422532096   42.845240  1.148501
# 21540  1237678617974538452   462857042382579712   45.384594  1.248257
#
#        modelMag_u  modelMag_g  modelMag_r  modelMag_i  modelMag_z  \
# 0        21.04576    19.13633    18.24454    17.80636    17.49794
# 1        20.76806    19.62210    19.13410    18.80635    18.65836
# 2        20.45433    18.53984    17.59312    17.19148    16.80270
# 3        17.69172    16.47214    16.03583    15.88817    15.80522
# 4        21.86385    20.02797    19.47907    19.11540    18.81272
# ...           ...         ...         ...         ...         ...
# 21536    19.63723    18.41523    17.84743    17.45326    17.25182
# 21537    19.67763    18.31304    17.75179    17.37725    17.12214
# 21538    20.04137    18.96305    18.49113    18.19909    18.07179
# 21539    19.83836    17.73394    16.77602    16.33247    15.98942
# 21540    19.38315    18.13665    17.50508    17.05358    16.82872
#
# 21528    18.20172    16.22911    15.36163    14.94751    14.63026
# 21531    19.44574    17.68412    16.87997    16.50182    16.28523
# 21535    19.43730    18.18862    17.60723    17.25635    17.00057
# 21536    19.63723    18.41523    17.84743    17.45326    17.25182
# 21540    19.38315    18.13665    17.50508    17.05358    16.82872
#
#        modelMagErr_u  ...  mag_ab_u  mag_ab_g  mag_ab_r  mag_ab_i  mag_ab_z  \
# 3           0.011567  ...  17.32434  16.20703  15.86566  15.73882  15.70032
# 9           0.031804  ...  18.62473  16.74175  15.77437  15.36412  15.01761
# 12          0.012726  ...  17.52560  15.84056  15.24307  15.09374  15.11472
# 16          0.043883  ...  19.11528  17.25905  16.34434  15.95839  15.63714
# 17          0.024788  ...  17.61186  16.46965  16.05821  15.70314  15.53221
# ...              ...  ...       ...       ...       ...       ...       ...
# 21528       0.024373  ...  17.92060  16.06614  15.19985  14.82109  14.53197
# 21531       0.024378  ...  17.91032  16.50887  16.08017  15.88459  15.83231
# 21535       0.046604  ...  18.39819  17.38578  17.09905  16.78993  16.66999
# 21536       0.045510  ...  19.16071  18.10534  17.63430  17.15122  17.04182
# 21540       0.046288  ...  18.96241  17.85497  17.32899  16.78946  16.65760
#
#        s2n_mag_u   s2n_mag_g   s2n_mag_r   s2n_mag_i   s2n_mag_z
# 3      86.450299  250.006375  236.375829  219.470549  145.624805
# 9      31.442645  241.636128  293.225809  298.309243  157.496908
# 12     78.581571  286.532951  304.121269  299.734316  194.726722
# 16     22.787665  181.368915  229.524888  228.974843  116.837103
# 17     40.341776  215.094192  216.085677  194.156812   66.709183
# ...          ...         ...         ...         ...         ...
# 21528  41.028587  295.539627  363.597227  368.272309  220.268538
# 21531  41.020390  199.039792  228.390908  230.103735  128.036071
# 21535  21.457505  131.250924  150.573406  137.816143   54.263217
# 21536  21.973077  107.178368  133.771229  133.390531   53.975163
# 21540  21.603825  127.997297  153.165111  154.567007   65.604142
#
# [5430 rows x 57 columns]

# %%
high_s2n_all.to_csv('../../Data/Stripe82_highs2n.csv', index=False)

# %%
palette = ['#feedde','#fdbe85','#fd8d3c','#e6550d','#a63603']

# %%
plt.rcParams.update(plotpars)
plt.plot(high_s2n_all['photoZ'], high_s2n_all['absMagR'], 'o', alpha=0.5, color=palette[2], 
         label='Sample with high S/N in all bands  \n (>20 $u$ and >50 $griz$)')
plt.legend(loc='best')
# plt.plot(stripe82_final['photoZ'].values[6], stripe82_final['absMagR'].values[6], 'o', alpha=1, color=palette[3])
plt.gca().invert_yaxis()
plt.ylabel("M$_r$")
plt.xlabel("$z$")
plt.savefig(os.path.join('../../Figures/', 'magr_redshift_uband20.png'))
plt.savefig(os.path.join('../../Figures/', 'magr_redshift_uband20.pdf'))
plt.show()

# %%
print(high_s2n_all['DR16_objID'].values.size)
# Out:
# 5430

# %% [markdown]
# # Random checks

# %%
np.unique(stripe82_all['probability_star'].values)
# Out:
# array([0])
